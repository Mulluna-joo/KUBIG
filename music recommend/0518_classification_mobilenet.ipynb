# %%
# Import Libraries
import warnings
warnings.filterwarnings('ignore')
import time
import numpy as np
import pandas as pd
pd.options.display.float_format = '{:.2f}'.format
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
# 모델의 reproducibility를 위해 학습 환경 및 random seed 고정
import numpy as np
import tensorflow as tf
import random

seed_num = 256
np.random.seed(seed_num)
random.seed(seed_num)
tf.random.set_seed(seed_num)

from keras import backend as K

session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads = 1,
                                        inter_op_parallelism_threads = 1)
sess = tf.compat.v1.Session(graph = tf.compat.v1.get_default_graph(), config = session_conf)
K.set_session(sess)

# %%
#모델 라이브러리 가져오기 
import itertools
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from keras import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
from keras.layers import Flatten,Dense,BatchNormalization,Activation,Dropout
import tensorflow as tf
from tensorflow.keras import layers
from keras.preprocessing.image import ImageDataGenerator
import keras
from keras.preprocessing.image import ImageDataGenerator

# %%
#import resnet
from tensorflow.keras.applications import resnet50

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
x_train = np.load('/content/drive/Shareddrives/2022-1 KUBIG 음악추천시스템/melspectogram.npy')

# %%
# %cd /content/drive/Shareddrives/2022-1 KUBIG 음악추천시스템
# Out:
# /content/drive/Shareddrives/2022-1 KUBIG 음악추천시스템

# %%
target = []
for i in range(200):
  target.append(0)
for i in range(200):
  target.append(1)
for i in range(200):
  target.append(2)
for i in range(200):
  target.append(3)

# %%
y_train = np.array(target)

# %%
x_train.shape

x_train= np.concatenate([x_train[0:200], x_train[400:]])

# %%
x_train.shape
# Out:
# (800, 128, 2584)

# %%
import cv2
cv2.resize(x_train[0], (256, 256), interpolation = cv2.INTER_LANCZOS4).shape


from sklearn.preprocessing import StandardScaler

new = []
for i in range(800):
  scaler = StandardScaler()
  temp = scaler.fit_transform(x_train[i])
  new.append(cv2.resize(temp, (256, 256), interpolation = cv2.INTER_LANCZOS4))

# %%
new2 = []
for i in range(800):
  new2.append(np.array([new[i], new[i], new[i]]))

# %%
x_train = np.array(new2)

# %%
x_train.shape
# Out:
# (800, 3, 256, 256)

# %%
x_train = np.swapaxes(np.swapaxes(x_train, 1, 2), 2, 3)

# %%
x_train.shape
# Out:
# (800, 256, 256, 3)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_train, y_train, random_state = 256, test_size = 0.2)

# %%
model=tf.keras.applications.MobileNet(include_top = False, weights = 'imagenet', input_shape = (256, 256, 3))

for layer in model.layers[:]:
    layer.trainable = False

flattened = tf.keras.layers.Flatten()(model.output)

fc1 = tf.keras.layers.Dense(5, activation='softmax', name="AddedDense2")(flattened)

model = tf.keras.models.Model(inputs=model.input, outputs=fc1)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
# 모델 컴파일
model.compile(optimizer ='adamax',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

print('Model Details are : ')
print(model.summary())
# Out:
# Model Details are :
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv1 (Conv2D)              (None, 128, 128, 32)      864
#
#  conv1_bn (BatchNormalizatio  (None, 128, 128, 32)     128
#  n)
#
#  conv1_relu (ReLU)           (None, 128, 128, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 128, 128, 32)     288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 128, 128, 32)     128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 128, 128, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 128, 128, 64)      2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 128, 128, 64)     256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 128, 128, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 129, 129, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 64, 64, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 64, 64, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 64, 64, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 64, 64, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 64, 64, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 64, 64, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 64, 64, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 64, 64, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 64, 64, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 64, 64, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 64, 64, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 64, 64, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 65, 65, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 32, 32, 128)      1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 32, 32, 128)      512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 32, 32, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 32, 32, 256)       32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 32, 32, 256)      1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 32, 32, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 32, 32, 256)      2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 32, 32, 256)      1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 32, 32, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 32, 32, 256)       65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 32, 32, 256)      1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 32, 32, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 33, 33, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 16, 16, 256)      2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 16, 16, 256)      1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 16, 16, 256)       0
#
#  conv_pw_6 (Conv2D)          (None, 16, 16, 512)       131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 16, 16, 512)      2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 16, 16, 512)       0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 16, 16, 512)      4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 16, 16, 512)      2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 16, 16, 512)       0
#
#  conv_pw_7 (Conv2D)          (None, 16, 16, 512)       262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 16, 16, 512)      2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 16, 16, 512)       0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 16, 16, 512)      4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 16, 16, 512)      2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 16, 16, 512)       0
#
#  conv_pw_8 (Conv2D)          (None, 16, 16, 512)       262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 16, 16, 512)      2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 16, 16, 512)       0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 16, 16, 512)      4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 16, 16, 512)      2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 16, 16, 512)       0
#
#  conv_pw_9 (Conv2D)          (None, 16, 16, 512)       262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 16, 16, 512)      2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 16, 16, 512)       0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 16, 16, 512)      4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 16, 16, 512)      2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 16, 16, 512)       0
#
#  conv_pw_10 (Conv2D)         (None, 16, 16, 512)       262144
#
#  conv_pw_10_bn (BatchNormali  (None, 16, 16, 512)      2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 16, 16, 512)       0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 16, 16, 512)      4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 16, 16, 512)      2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 16, 16, 512)       0
#
#  conv_pw_11 (Conv2D)         (None, 16, 16, 512)       262144
#
#  conv_pw_11_bn (BatchNormali  (None, 16, 16, 512)      2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 16, 16, 512)       0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 17, 17, 512)      0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 8, 8, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 8, 8, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 8, 8, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 8, 8, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 8, 8, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 8, 8, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 8, 8, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 8, 8, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 8, 8, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 8, 8, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 8, 8, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 8, 8, 1024)        0
#
#  flatten_1 (Flatten)         (None, 65536)             0
#
#  AddedDense2 (Dense)         (None, 5)                 327685
#
# =================================================================
# Total params: 3,556,549
# Trainable params: 327,685
# Non-trainable params: 3,228,864
# _________________________________________________________________
# None

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score

kfold = 5
skf = StratifiedKFold(n_splits = kfold, shuffle = True, random_state = 256)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
y_train.shape
# Out:
# (640,)

# %%
X_train.shape

# %%
testpred = []
testprob = []

for i, (train_index, val_index) in enumerate(skf.split(X_train, y_train)):
    
    print('[Fold %d/%d]' % (i + 1, kfold))
    
    
    trainx, validx = X_train[train_index], X_train[val_index]
    trainy, validy = y_train[train_index], y_train[val_index]

 
    callbacks_list = [  
      ModelCheckpoint('/content/drive/MyDrive/musicrecommendation_mobilenetwithoutdance{zero}.h5'.format(zero = i), monitor='val_accuracy', mode='max', verbose = 1, save_best_only = True),
      EarlyStopping(patience=8, verbose = 1),
      ReduceLROnPlateau(patience=4, verbose=1)
    ]  

    ThisModel = model.fit(trainx, trainy, validation_data = (validx, validy), batch_size=32, epochs=100, callbacks=callbacks_list, verbose=1)
# Out:
# [Fold 1/5]
# Epoch 1/100
# 16/16 [==============================] - ETA: 0s - loss: 6.2736 - accuracy: 0.4316
# Epoch 1: val_accuracy improved from -inf to 0.59375, saving model to /content/drive/MyDrive/musicrecommendation_mobilenetwithoutdance0.h5
# 16/16 [==============================] - 6s 219ms/step - loss: 6.2736 - accuracy: 0.4316 - val_loss: 2.8123 - val_accuracy: 0.5938 - lr: 0.0010
# Epoch 2/100
# 16/16 [==============================] - ETA: 0s - loss: 1.5060 - accuracy: 0.7324
# Epoch 2: val_accuracy improved from 0.59375 to 0.64062, saving model to /content/drive/MyDrive/musicrecommendation_mobilenetwithoutdance0.h5
# 16/16 [==============================] - 2s 114ms/step - loss: 1.5060 - accuracy: 0.7324 - val_loss: 2.3829 - val_accuracy: 0.6406 - lr: 0.0010
# Epoch 3/100
# 16/16 [==============================] - ETA: 0s - loss: 0.5647 - accuracy: 0.8867
# Epoch 3: val_accuracy improved from 0.64062 to 0.70312, saving model to /content/drive/MyDrive/musicrecommendation_mobilenetwithoutdance0.h5
# 16/16 [==============================] - 2s 135ms/step - loss: 0.5647 - accuracy: 0.8867 - val_loss: 1.6718 - val_accuracy: 0.7031 - lr: 0.0010
# Epoch 4/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2132 - accuracy: 0.9336
# Epoch 4: val_accuracy did not improve from 0.70312
# 16/16 [==============================] - 1s 94ms/step - loss: 0.2132 - accuracy: 0.9336 - val_loss: 1.4057 - val_accuracy: 0.7031 - lr: 0.0010
# Epoch 5/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0767 - accuracy: 0.9746
# Epoch 5: val_accuracy improved from 0.70312 to 0.72656, saving model to /content/drive/MyDrive/musicrecommendation_mobilenetwithoutdance0.h5
# 16/16 [==============================] - 2s 100ms/step - loss: 0.0767 - accuracy: 0.9746 - val_loss: 1.2582 - val_accuracy: 0.7266 - lr: 0.0010
# Epoch 6/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0525 - accuracy: 0.9766
# Epoch 6: val_accuracy did not improve from 0.72656
# 16/16 [==============================] - 1s 75ms/step - loss: 0.0525 - accuracy: 0.9766 - val_loss: 1.3002 - val_accuracy: 0.7266 - lr: 0.0010
# Epoch 7/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9980
# Epoch 7: val_accuracy improved from 0.72656 to 0.76562, saving model to /content/drive/MyDrive/musicrecommendation_mobilenetwithoutdance0.h5
# 16/16 [==============================] - 1s 88ms/step - loss: 0.0228 - accuracy: 0.9980 - val_loss: 1.2216 - val_accuracy: 0.7656 - lr: 0.0010
# Epoch 8/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 1.0000
# Epoch 8: val_accuracy did not improve from 0.76562
# 16/16 [==============================] - 1s 68ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 1.1617 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 9/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 9: val_accuracy did not improve from 0.76562
# 16/16 [==============================] - 1s 69ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 1.1752 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 10/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 0.76562
# 16/16 [==============================] - 1s 69ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 1.1787 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 11/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 0.76562
# 16/16 [==============================] - 1s 69ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.1727 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 12/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 0.76562
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 16/16 [==============================] - 1s 68ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 1.1671 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 13/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.76562
# 16/16 [==============================] - 1s 68ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.1669 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 14/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.76562
# 16/16 [==============================] - 1s 67ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.1669 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 15/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 0.76562
# 16/16 [==============================] - 1s 75ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.1674 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 16/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 16: val_accuracy did not improve from 0.76562
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 16/16 [==============================] - 1s 76ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.1672 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 16: early stopping
# [Fold 2/5]
# Epoch 1/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2959 - accuracy: 0.9375
# Epoch 1: val_accuracy improved from -inf to 1.00000, saving model to /content/drive/MyDrive/musicrecommendation_mobilenetwithoutdance1.h5
# 16/16 [==============================] - 2s 96ms/step - loss: 0.2959 - accuracy: 0.9375 - val_loss: 0.0061 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 2/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2924 - accuracy: 0.9375
# Epoch 2: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 67ms/step - loss: 0.2924 - accuracy: 0.9375 - val_loss: 0.0060 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 3/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2883 - accuracy: 0.9375
# Epoch 3: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 75ms/step - loss: 0.2883 - accuracy: 0.9375 - val_loss: 0.0060 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 4/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2835 - accuracy: 0.9375
# Epoch 4: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 68ms/step - loss: 0.2835 - accuracy: 0.9375 - val_loss: 0.0060 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 5/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2791 - accuracy: 0.9375
# Epoch 5: val_accuracy did not improve from 1.00000
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 16/16 [==============================] - 1s 67ms/step - loss: 0.2791 - accuracy: 0.9375 - val_loss: 0.0060 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 6/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2755 - accuracy: 0.9395
# Epoch 6: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 75ms/step - loss: 0.2755 - accuracy: 0.9395 - val_loss: 0.0060 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 7/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2751 - accuracy: 0.9395
# Epoch 7: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 69ms/step - loss: 0.2751 - accuracy: 0.9395 - val_loss: 0.0060 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 8/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2747 - accuracy: 0.9395
# Epoch 8: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 68ms/step - loss: 0.2747 - accuracy: 0.9395 - val_loss: 0.0060 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 9/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2742 - accuracy: 0.9395
# Epoch 9: val_accuracy did not improve from 1.00000
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 16/16 [==============================] - 1s 75ms/step - loss: 0.2742 - accuracy: 0.9395 - val_loss: 0.0060 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 10/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2738 - accuracy: 0.9395
# Epoch 10: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 68ms/step - loss: 0.2738 - accuracy: 0.9395 - val_loss: 0.0060 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 11/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2738 - accuracy: 0.9395
# Epoch 11: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 68ms/step - loss: 0.2738 - accuracy: 0.9395 - val_loss: 0.0060 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 12/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2737 - accuracy: 0.9395
# Epoch 12: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 68ms/step - loss: 0.2737 - accuracy: 0.9395 - val_loss: 0.0060 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 12: early stopping
# [Fold 3/5]
# Epoch 1/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2739 - accuracy: 0.9395
# Epoch 1: val_accuracy improved from -inf to 1.00000, saving model to /content/drive/MyDrive/musicrecommendation_mobilenetwithoutdance2.h5
# 16/16 [==============================] - 2s 100ms/step - loss: 0.2739 - accuracy: 0.9395 - val_loss: 0.0052 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 2/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2738 - accuracy: 0.9395
# Epoch 2: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 66ms/step - loss: 0.2738 - accuracy: 0.9395 - val_loss: 0.0052 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 3/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2738 - accuracy: 0.9395
# Epoch 3: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 68ms/step - loss: 0.2738 - accuracy: 0.9395 - val_loss: 0.0052 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 4/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2737 - accuracy: 0.9395
# Epoch 4: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 69ms/step - loss: 0.2737 - accuracy: 0.9395 - val_loss: 0.0052 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 5/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2737 - accuracy: 0.9395
# Epoch 5: val_accuracy did not improve from 1.00000
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 16/16 [==============================] - 1s 67ms/step - loss: 0.2737 - accuracy: 0.9395 - val_loss: 0.0052 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 6/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2856 - accuracy: 0.9396
# Epoch 6: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 69ms/step - loss: 0.2737 - accuracy: 0.9395 - val_loss: 0.0052 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 7/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2737 - accuracy: 0.9395
# Epoch 7: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 67ms/step - loss: 0.2737 - accuracy: 0.9395 - val_loss: 0.0052 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 8/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2736 - accuracy: 0.9395
# Epoch 8: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 68ms/step - loss: 0.2736 - accuracy: 0.9395 - val_loss: 0.0052 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 9/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2736 - accuracy: 0.9395
# Epoch 9: val_accuracy did not improve from 1.00000
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 16/16 [==============================] - 1s 68ms/step - loss: 0.2736 - accuracy: 0.9395 - val_loss: 0.0052 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 9: early stopping
# [Fold 4/5]
# Epoch 1/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2734 - accuracy: 0.9395
# Epoch 1: val_accuracy improved from -inf to 1.00000, saving model to /content/drive/MyDrive/musicrecommendation_mobilenetwithoutdance3.h5
# 16/16 [==============================] - 2s 99ms/step - loss: 0.2734 - accuracy: 0.9395 - val_loss: 0.0061 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 2/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2734 - accuracy: 0.9395
# Epoch 2: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 67ms/step - loss: 0.2734 - accuracy: 0.9395 - val_loss: 0.0061 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 3/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2734 - accuracy: 0.9395
# Epoch 3: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 67ms/step - loss: 0.2734 - accuracy: 0.9395 - val_loss: 0.0061 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 4/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2734 - accuracy: 0.9395
# Epoch 4: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 67ms/step - loss: 0.2734 - accuracy: 0.9395 - val_loss: 0.0061 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 5/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2734 - accuracy: 0.9395
# Epoch 5: val_accuracy did not improve from 1.00000
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
# 16/16 [==============================] - 1s 68ms/step - loss: 0.2734 - accuracy: 0.9395 - val_loss: 0.0061 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 6/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2734 - accuracy: 0.9395
# Epoch 6: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 68ms/step - loss: 0.2734 - accuracy: 0.9395 - val_loss: 0.0061 - val_accuracy: 1.0000 - lr: 1.0000e-10
# Epoch 7/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2734 - accuracy: 0.9395
# Epoch 7: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 68ms/step - loss: 0.2734 - accuracy: 0.9395 - val_loss: 0.0061 - val_accuracy: 1.0000 - lr: 1.0000e-10
# Epoch 8/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2734 - accuracy: 0.9395
# Epoch 8: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 69ms/step - loss: 0.2734 - accuracy: 0.9395 - val_loss: 0.0061 - val_accuracy: 1.0000 - lr: 1.0000e-10
# Epoch 9/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2734 - accuracy: 0.9395
# Epoch 9: val_accuracy did not improve from 1.00000
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-11.
# 16/16 [==============================] - 1s 66ms/step - loss: 0.2734 - accuracy: 0.9395 - val_loss: 0.0061 - val_accuracy: 1.0000 - lr: 1.0000e-10
# Epoch 9: early stopping
# [Fold 5/5]
# Epoch 1/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2737 - accuracy: 0.9395
# Epoch 1: val_accuracy improved from -inf to 1.00000, saving model to /content/drive/MyDrive/musicrecommendation_mobilenetwithoutdance4.h5
# 16/16 [==============================] - 2s 99ms/step - loss: 0.2737 - accuracy: 0.9395 - val_loss: 0.0048 - val_accuracy: 1.0000 - lr: 1.0000e-11
# Epoch 2/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2737 - accuracy: 0.9395
# Epoch 2: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 68ms/step - loss: 0.2737 - accuracy: 0.9395 - val_loss: 0.0048 - val_accuracy: 1.0000 - lr: 1.0000e-11
# Epoch 3/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2737 - accuracy: 0.9395
# Epoch 3: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 86ms/step - loss: 0.2737 - accuracy: 0.9395 - val_loss: 0.0048 - val_accuracy: 1.0000 - lr: 1.0000e-11
# Epoch 4/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2737 - accuracy: 0.9395
# Epoch 4: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 82ms/step - loss: 0.2737 - accuracy: 0.9395 - val_loss: 0.0048 - val_accuracy: 1.0000 - lr: 1.0000e-11
# Epoch 5/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2737 - accuracy: 0.9395
# Epoch 5: val_accuracy did not improve from 1.00000
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-12.
# 16/16 [==============================] - 1s 95ms/step - loss: 0.2737 - accuracy: 0.9395 - val_loss: 0.0048 - val_accuracy: 1.0000 - lr: 1.0000e-11
# Epoch 6/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2737 - accuracy: 0.9395
# Epoch 6: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 94ms/step - loss: 0.2737 - accuracy: 0.9395 - val_loss: 0.0048 - val_accuracy: 1.0000 - lr: 1.0000e-12
# Epoch 7/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2737 - accuracy: 0.9395
# Epoch 7: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 2s 96ms/step - loss: 0.2737 - accuracy: 0.9395 - val_loss: 0.0048 - val_accuracy: 1.0000 - lr: 1.0000e-12
# Epoch 8/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2737 - accuracy: 0.9395
# Epoch 8: val_accuracy did not improve from 1.00000
# 16/16 [==============================] - 1s 95ms/step - loss: 0.2737 - accuracy: 0.9395 - val_loss: 0.0048 - val_accuracy: 1.0000 - lr: 1.0000e-12
# Epoch 9/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2737 - accuracy: 0.9395
# Epoch 9: val_accuracy did not improve from 1.00000
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.0000001044244145e-13.
# 16/16 [==============================] - 1s 82ms/step - loss: 0.2737 - accuracy: 0.9395 - val_loss: 0.0048 - val_accuracy: 1.0000 - lr: 1.0000e-12
# Epoch 9: early stopping

# %%
testpred
# Out:
# []

# %%
testprob
# Out:
# []

# %%
for i in range(5):
  sum = 0
  sum_list = []
  for j in range(len(testpred[i])):
    if testpred[i][j] == y_test[j]:
      sum = sum + 1
  print(sum / len(testpred[1]) * 100)
  sum_list.append(sum / len(testpred[1]) * 100)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-55-2f2549afea03> in <module>()
#       2   sum = 0
#       3   sum_list = []
# ----> 4   for j in range(len(testpred[i])):
#       5     if testpred[i][j] == y_test[j]:
#       6       sum = sum + 1
#
# IndexError: list index out of range

# %%
np.mean(sum_list)

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
def calculate_tpr_fpr(y_real, y_pred):
    '''
    Calculates the True Positive Rate (tpr) and the True Negative Rate (fpr) based on real and predicted observations
    
    Args:
        y_real: The list or series with the real classes
        y_pred: The list or series with the predicted classes
        
    Returns:
        tpr: The True Positive Rate of the classifier
        fpr: The False Positive Rate of the classifier
    '''
    
    # Calculates the confusion matrix and recover each element
    cm = confusion_matrix(y_real, y_pred)
    TN = cm[0, 0]
    FP = cm[0, 1]
    FN = cm[1, 0]
    TP = cm[1, 1]
    
    # Calculates tpr and fpr
    tpr =  TP/(TP + FN) # sensitivity - true positive rate
    fpr = 1 - TN/(TN+FP) # 1-specificity - false positive rate
    
    return tpr, fpr

# %%
def get_all_roc_coordinates(y_real, y_proba):
    '''
    Calculates all the ROC Curve coordinates (tpr and fpr) by considering each point as a treshold for the predicion of the class.
    
    Args:
        y_real: The list or series with the real classes.
        y_proba: The array with the probabilities for each class, obtained by using the `.predict_proba()` method.
        
    Returns:
        tpr_list: The list of TPRs representing each threshold.
        fpr_list: The list of FPRs representing each threshold.
    '''
    tpr_list = [0]
    fpr_list = [0]
    for i in range(len(y_proba)):
        threshold = y_proba[i]
        y_pred = y_proba >= threshold
        tpr, fpr = calculate_tpr_fpr(y_real, y_pred)
        tpr_list.append(tpr)
        fpr_list.append(fpr)
    return tpr_list, fpr_list

# %%
def plot_roc_curve_blue(tpr, fpr, scatter = True, ax = None):
    '''
    Plots the ROC Curve by using the list of coordinates (tpr and fpr).
    
    Args:
        tpr: The list of TPRs representing each coordinate.
        fpr: The list of FPRs representing each coordinate.
        scatter: When True, the points used on the calculation will be plotted with the line (default = True).
    '''
    if ax == None:
        plt.figure(figsize = (5, 5))
        ax = plt.axes()
    
    if scatter:
        sns.scatterplot(x = fpr, y = tpr, ax = ax)
    sns.lineplot(x = fpr, y = tpr, ax = ax, ci=None, color='skyblue', alpha = 0.08)
    sns.lineplot(x = [0, 1], y = [0, 1], color = 'black', ax = ax, alpha = 0.05, linestyle='--')
    plt.xlim(-0.05, 1.05)
    plt.ylim(-0.05, 1.05)
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")

# %%
def plot_roc_curve_red(tpr, fpr, scatter = True, ax = None):
    '''
    Plots the ROC Curve by using the list of coordinates (tpr and fpr).
    
    Args:
        tpr: The list of TPRs representing each coordinate.
        fpr: The list of FPRs representing each coordinate.
        scatter: When True, the points used on the calculation will be plotted with the line (default = True).
    '''
    if ax == None:
        plt.figure(figsize = (5, 5))
        ax = plt.axes()
    
    if scatter:
        sns.scatterplot(x = fpr, y = tpr, ax = ax)
    sns.lineplot(x = fpr, y = tpr, ax = ax, ci=None, color='red', alpha = 0.08)
    sns.lineplot(x = [0, 1], y = [0, 1], color = 'black', ax = ax, alpha = 0.05, linestyle='--')
    plt.xlim(-0.05, 1.05)
    plt.ylim(-0.05, 1.05)
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")

# %%
def plot_roc_curve_red_2(tpr, fpr, scatter = True, ax = None):
    '''
    Plots the ROC Curve by using the list of coordinates (tpr and fpr).
    
    Args:
        tpr: The list of TPRs representing each coordinate.
        fpr: The list of FPRs representing each coordinate.
        scatter: When True, the points used on the calculation will be plotted with the line (default = True).
    '''
    if ax == None:
        plt.figure(figsize = (5, 5))
        ax = plt.axes()
    
    if scatter:
        sns.scatterplot(x = fpr, y = tpr, ax = ax)
    sns.lineplot(x = fpr, y = tpr, ax = ax, ci=None, color='red', alpha = 1)
    plt.xlim(-0.05, 1.05)
    plt.ylim(-0.05, 1.05)
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")

# %%
classes = [0, 1, 2, 3, 4]
classes

# %%
classes_names = ['Hip hop', 'Dance', 'Trot', 'Ballad', 'Rock']

# %%
from sklearn.metrics import confusion_matrix, roc_auc_score, auc
import seaborn as sns

# %%
plt.figure(figsize = (12, 8))
roc_auc_ovr = {}
auc = []
    
for i in range(len(classes)):
    
    temptpr = []
    tempfpr = []
    
    for j in range(5):

        c = classes[i]

        df_aux = pd.DataFrame(y_test).copy()
        df_aux['class'] = [1 if y == c else 0 for y in y_test]
        df_aux['prob'] = np.array(testprob)[j][:, i]
        df_aux = df_aux.reset_index(drop = True)

        ax_bottom = plt.subplot(2, 3, i+2)
        tpr, fpr = get_all_roc_coordinates(df_aux['class'], df_aux['prob'])


        temptpr.append(tpr)
        tempfpr.append(fpr)
        
        plot_roc_curve_red(tpr, fpr, scatter = False, ax = ax_bottom)
        
        
        ax_bottom.set_title(f"ROC Curve OvR: {classes_names[c]} vs. Rest")

        auc.append(roc_auc_score(df_aux['class'], df_aux['prob']))
    
    temptpr = np.array(temptpr)
    tempfpr = np.array(tempfpr)
    
    num = 9 + i * 10
    prev = 9 + (i-1)*10
    plot_roc_curve_red_2(np.sort(np.array(pd.DataFrame(temptpr).mean())), np.sort(np.array(pd.DataFrame(tempfpr).mean())), scatter = False, ax = ax_bottom)

    plt.tight_layout()

# %%
auc[:5]

# %%
np.mean(auc[:5])

# %%
auc[5:10]

# %%
np.mean(auc[5:10])

# %%
auc[10:15]

# %%
np.mean(auc[10:15])

# %%
auc[15:20]

# %%
np.mean(auc[15:20])

# %%
auc[20:25]

# %%
np.mean(auc[20:25])

# %%
totalauc = [np.mean(auc[:5]), np.mean(auc[5:10]), np.mean(auc[10:15]), np.mean(auc[15:20]), np.mean(auc[20:25])]
np.mean(totalauc)

# %%
from sklearn.metrics import precision_recall_fscore_support

sens0 = []
spec0 = []
sens1 = []
spec1 = []
sens2 = []
spec2 = []
sens3 = []
spec3 = []
sens4 = []
spec4 = []

for i in range(5):
    for l in [0, 1, 2, 3, 4]:
        prec, recall, _, _ = precision_recall_fscore_support(np.array(y_test) == l, testpred[i] == l, pos_label = True, average = None)
        if l == 0:
            sens0.append(recall[0])
            spec0.append(recall[1])
        elif l == 1:
            sens1.append(recall[0])
            spec1.append(recall[1])
        elif l == 2:
            sens2.append(recall[0])
            spec2.append(recall[1])
        elif l == 3:
            sens3.append(recall[0])
            spec3.append(recall[1])
        else:
            sens4.append(recall[0])
            spec4.append(recall[1])
            
df = [[np.mean(sens0), np.mean(spec0)], [np.mean(sens1), np.mean(spec1)], [np.mean(sens2), np.mean(spec2)], [np.mean(sens3), np.mean(spec3)], [np.mean(sens4), np.mean(spec4)]]
print(pd.DataFrame(df))
print(pd.DataFrame(df).mean(axis=0))

# %%
## simplernn
## lstm
## gru

## resnet50
## inception / xception
## senet (그냥...)
## vision transformer

## cosine similiarity
## p-norm


## 1. 본인 장르 30개 더
## 2. 7788 / 상준 승은 지호 지우
## 3. 지호 지우 추천시스템 (함수 만들기) - cv 모델 느낌만
## 4. 상준 승은 다 하기
