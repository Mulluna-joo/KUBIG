# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
temp = ['zero_crossing_rate', 'zero_crossings', 'spectrogram', 'harmonics', 'perceptual_shock_wave', 'specral_centroids', 'chroma1', 'chroma2', 'chroma3', 'chroma4', 'chroma5', 'chroma6', 'chroma7', 'chroma8', 'chroma9', 'chroma10', 'chroma11', 'chroma12', 'tempo_bpm', 'spectral_rolloff', 'spectral_bandwidth_2', 'spectral_bandwidth_3', 'spectral_bandwidth_4']

# %%
a = pd.read_csv('/content/drive/Shareddrives/2022-1 KUBIG 음악추천시스템/features.csv')

# %%
a
# Out:
#             0        1          2             3         4            5  \
# 0    0.046239  61226.0 -58.389446  1.497771e-05  0.000028  2273.314455
# 1    0.064877  85947.0 -41.730743 -1.490692e-04  0.000508  3494.625619
# 2    0.067064  88879.0 -47.616371  1.891724e-03  0.003400  2866.068566
# 3    0.052821  69942.0 -49.600529  1.110476e-04  0.001069  2434.705921
# 4    0.066571  88149.0 -44.962914 -8.150877e-05 -0.001115  3131.318374
# ..        ...      ...        ...           ...       ...          ...
# 995  0.050047  66251.0 -41.708935  3.613922e-05  0.000057  2815.130200
# 996  0.051887  68702.0 -46.168499 -8.458334e-07 -0.000270  2317.351918
# 997  0.040793  54016.0 -39.201550  1.300343e-04  0.000796  2410.326432
# 998  0.063838  84515.0 -43.814190  6.587733e-05  0.000384  3026.845374
# 999  0.067664  89571.0 -43.625828  1.944064e-05  0.000048  3326.510694
#
#             6         7         8         9  ...        13        14  \
# ...

# %%
a.columns = temp

# %%
a
# Out:
#      zero_crossing_rate  zero_crossings  spectrogram     harmonics  \
# 0              0.046239         61226.0   -58.389446  1.497771e-05
# 1              0.064877         85947.0   -41.730743 -1.490692e-04
# 2              0.067064         88879.0   -47.616371  1.891724e-03
# 3              0.052821         69942.0   -49.600529  1.110476e-04
# 4              0.066571         88149.0   -44.962914 -8.150877e-05
# ..                  ...             ...          ...           ...
# 995            0.050047         66251.0   -41.708935  3.613922e-05
# 996            0.051887         68702.0   -46.168499 -8.458334e-07
# 997            0.040793         54016.0   -39.201550  1.300343e-04
# 998            0.063838         84515.0   -43.814190  6.587733e-05
# 999            0.067664         89571.0   -43.625828  1.944064e-05
#
#      perceptual_shock_wave  specral_centroids   chroma1   chroma2   chroma3  \
# 0                 0.000028        2273.314455  0.439173  0.485530  0.401174
# ...

# %%
b = pd.read_csv('/content/drive/Shareddrives/2022-1 KUBIG 음악추천시스템/metadata.csv', encoding='cp949').drop('id', axis=1)
b
# Out:
#                                               tittle  \
# 0             회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)
# 1                      리무진 (Feat. MINO) (Prod. GRAY)
# 2                    Counting Stars (Feat. Beenzino)
# 3                                     OHAYO MY NIGHT
# 4     만남은 쉽고 이별은 어려워 (Feat. Leellamarz) (Prod. TOIL)
# ...                                              ...
# 1002                                             NaN
# 1003                                             NaN
# 1004                                             NaN
# 1005                                             NaN
# 1006                                             NaN
#
#                          artist release_date genre
# 0                      sokodomo   2021.11.13    힙합
# 1                     BE'O (비오)   2021.11.20    힙합
# 2                     BE'O (비오)   2021.12.12    힙합
# 3     디핵 (D-Hack), PATEKO (파테코)   2020.06.20    힙합
# 4                  베이식 (Basick)   2021.11.20    힙합
# ...

# %%
# b = b.drop(1007, axis = 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-8aa212933e96> in <module>()
# ----> 1 b = b.drop(1007, axis = 0)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %%
b
# Out:
#                                              tittle  \
# 0            회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)
# 1                     리무진 (Feat. MINO) (Prod. GRAY)
# 2                   Counting Stars (Feat. Beenzino)
# 3                                    OHAYO MY NIGHT
# 4    만남은 쉽고 이별은 어려워 (Feat. Leellamarz) (Prod. TOIL)
# ..                                              ...
# 995                                   낙하 (with 아이유)
# 996                                      I Love You
# 997                                  전쟁터 (with 이선희)
# 998                                          시간을 갖자
# 999                             BENCH (with Zion.T)
#
#                         artist release_date genre
# 0                     sokodomo   2021.11.13    힙합
# 1                    BE'O (비오)   2021.11.20    힙합
# 2                    BE'O (비오)   2021.12.12    힙합
# 3    디핵 (D-Hack), PATEKO (파테코)   2020.06.20    힙합
# 4                 베이식 (Basick)   2021.11.20    힙합
# ...

# %%
a
# Out:
#      zero_crossing_rate  zero_crossings  spectrogram     harmonics  \
# 0              0.046239         61226.0   -58.389446  1.497771e-05
# 1              0.064877         85947.0   -41.730743 -1.490692e-04
# 2              0.067064         88879.0   -47.616371  1.891724e-03
# 3              0.052821         69942.0   -49.600529  1.110476e-04
# 4              0.066571         88149.0   -44.962914 -8.150877e-05
# ..                  ...             ...          ...           ...
# 995            0.050047         66251.0   -41.708935  3.613922e-05
# 996            0.051887         68702.0   -46.168499 -8.458334e-07
# 997            0.040793         54016.0   -39.201550  1.300343e-04
# 998            0.063838         84515.0   -43.814190  6.587733e-05
# 999            0.067664         89571.0   -43.625828  1.944064e-05
#
#      perceptual_shock_wave  specral_centroids   chroma1   chroma2   chroma3  \
# 0                 0.000028        2273.314455  0.439173  0.485530  0.401174
# ...

# %%
# %cd /content/drive/Shareddrives/2022-1 KUBIG 음악추천시스템
# Out:
# /content/drive/Shareddrives/2022-1 KUBIG 음악추천시스템

# %%
# !pwd
# Out:
# /content/drive/Shareddrives/2022-1 KUBIG 음악추천시스템

# %%
a.to_csv('0511_features_sorted.csv')

# %%
b.to_csv('0511_metadata.csv')

# %%
target = []
for i in range(200):
  target.append(0)
for i in range(200):
  target.append(1)
for i in range(200):
  target.append(2)
for i in range(200):
  target.append(3)
for i in range(200):
  target.append(4)

# %%
len(target)
# Out:
# 1000

# %%
merged1 = pd.concat([a, b], axis = 1)

# %%
merged1['genre_num'] = target

# %%
merged1
# Out:
#      zero_crossing_rate  zero_crossings  spectrogram     harmonics  \
# 0              0.046239         61226.0   -58.389446  1.497771e-05
# 1              0.064877         85947.0   -41.730743 -1.490692e-04
# 2              0.067064         88879.0   -47.616371  1.891724e-03
# 3              0.052821         69942.0   -49.600529  1.110476e-04
# 4              0.066571         88149.0   -44.962914 -8.150877e-05
# ..                  ...             ...          ...           ...
# 995            0.050047         66251.0   -41.708935  3.613922e-05
# 996            0.051887         68702.0   -46.168499 -8.458334e-07
# 997            0.040793         54016.0   -39.201550  1.300343e-04
# 998            0.063838         84515.0   -43.814190  6.587733e-05
# 999            0.067664         89571.0   -43.625828  1.944064e-05
#
#      perceptual_shock_wave  specral_centroids   chroma1   chroma2   chroma3  \
# 0                 0.000028        2273.314455  0.439173  0.485530  0.401174
# ...

# %%
a['genre_num'] = target

# %%
a
# Out:
#      zero_crossing_rate  zero_crossings  spectrogram     harmonics  \
# 0              0.046239         61226.0   -58.389446  1.497771e-05
# 1              0.064877         85947.0   -41.730743 -1.490692e-04
# 2              0.067064         88879.0   -47.616371  1.891724e-03
# 3              0.052821         69942.0   -49.600529  1.110476e-04
# 4              0.066571         88149.0   -44.962914 -8.150877e-05
# ..                  ...             ...          ...           ...
# 995            0.050047         66251.0   -41.708935  3.613922e-05
# 996            0.051887         68702.0   -46.168499 -8.458334e-07
# 997            0.040793         54016.0   -39.201550  1.300343e-04
# 998            0.063838         84515.0   -43.814190  6.587733e-05
# 999            0.067664         89571.0   -43.625828  1.944064e-05
#
#      perceptual_shock_wave  specral_centroids   chroma1   chroma2   chroma3  \
# 0                 0.000028        2273.314455  0.439173  0.485530  0.401174
# ...

# %%
b['genre_num'] = target

# %%
b
# Out:
#                                              tittle  \
# 0            회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)
# 1                     리무진 (Feat. MINO) (Prod. GRAY)
# 2                   Counting Stars (Feat. Beenzino)
# 3                                    OHAYO MY NIGHT
# 4    만남은 쉽고 이별은 어려워 (Feat. Leellamarz) (Prod. TOIL)
# ..                                              ...
# 995                                   낙하 (with 아이유)
# 996                                      I Love You
# 997                                  전쟁터 (with 이선희)
# 998                                          시간을 갖자
# 999                             BENCH (with Zion.T)
#
#                         artist release_date genre  genre_num
# 0                     sokodomo   2021.11.13    힙합          0
# 1                    BE'O (비오)   2021.11.20    힙합          0
# 2                    BE'O (비오)   2021.12.12    힙합          0
# 3    디핵 (D-Hack), PATEKO (파테코)   2020.06.20    힙합          0
# ...

# %%
merged1
# Out:
#      zero_crossing_rate  zero_crossings  spectrogram     harmonics  \
# 0              0.046239         61226.0   -58.389446  1.497771e-05
# 1              0.064877         85947.0   -41.730743 -1.490692e-04
# 2              0.067064         88879.0   -47.616371  1.891724e-03
# 3              0.052821         69942.0   -49.600529  1.110476e-04
# 4              0.066571         88149.0   -44.962914 -8.150877e-05
# ..                  ...             ...          ...           ...
# 995            0.050047         66251.0   -41.708935  3.613922e-05
# 996            0.051887         68702.0   -46.168499 -8.458334e-07
# 997            0.040793         54016.0   -39.201550  1.300343e-04
# 998            0.063838         84515.0   -43.814190  6.587733e-05
# 999            0.067664         89571.0   -43.625828  1.944064e-05
#
#      perceptual_shock_wave  specral_centroids   chroma1   chroma2   chroma3  \
# 0                 0.000028        2273.314455  0.439173  0.485530  0.401174
# ...

# %%
a.to_csv('0511_features_sorted.csv')

# %%
b.to_csv('0511_metadata_sorted.csv')

# %%
merged1.to_csv('0511_merged_sorted.csv')
